# %%
#Required for manipulating data

# !pip install pandas
# !pip install numpy
# !pip install gspread
# !pip install panel
# !pip install hvplot
# !pip install holoviews

import pandas as pd
pd.options.mode.chained_assignment = None
import numpy as np

#Required for building the interactive dashboard

import panel as pn
pn.extension('tabulator')
import hvplot.pandas
import holoviews as hv
hv.extension('bokeh')
# Out:
# Requirement already satisfied: pandas in c:\users\jake\anaconda3\lib\site-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\jake\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jake\anaconda3\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\jake\anaconda3\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in c:\users\jake\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: numpy in c:\users\jake\anaconda3\lib\site-packages (1.24.3)
# Requirement already satisfied: gspread in c:\users\jake\anaconda3\lib\site-packages (5.11.1)
# Requirement already satisfied: google-auth>=1.12.0 in c:\users\jake\anaconda3\lib\site-packages (from gspread) (2.22.0)
# Requirement already satisfied: google-auth-oauthlib>=0.4.1 in c:\users\jake\anaconda3\lib\site-packages (from gspread) (1.0.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\jake\anaconda3\lib\site-packages (from google-auth>=1.12.0->gspread) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\jake\anaconda3\lib\site-packages (from google-auth>=1.12.0->gspread) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\jake\anaconda3\lib\site-packages (from google-auth>=1.12.0->gspread) (4.9)
# Requirement already satisfied: six>=1.9.0 in c:\users\jake\anaconda3\lib\site-packages (from google-auth>=1.12.0->gspread) (1.16.0)
# Requirement already satisfied: urllib3<2.0 in c:\users\jake\anaconda3\lib\site-packages (from google-auth>=1.12.0->gspread) (1.26.16)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\jake\anaconda3\lib\site-packages (from google-auth-oauthlib>=0.4.1->gspread) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\jake\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.12.0->gspread) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\jake\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.2.2)
# Requirement already satisfied: requests>=2.0.0 in c:\users\jake\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.29.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jake\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jake\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jake\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2023.5.7)
# Requirement already satisfied: panel in c:\users\jake\anaconda3\lib\site-packages (1.1.0)
# Requirement already satisfied: bokeh<3.2.0,>=3.1.1 in c:\users\jake\anaconda3\lib\site-packages (from panel) (3.1.1)
# Requirement already satisfied: param>=1.12.0 in c:\users\jake\anaconda3\lib\site-packages (from panel) (1.13.0)
# Requirement already satisfied: pyviz-comms>=0.7.4 in c:\users\jake\anaconda3\lib\site-packages (from panel) (2.3.0)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\jake\anaconda3\lib\site-packages (from panel) (2022.9.0)
# Requirement already satisfied: markdown in c:\users\jake\anaconda3\lib\site-packages (from panel) (3.4.1)
# Requirement already satisfied: markdown-it-py<3 in c:\users\jake\anaconda3\lib\site-packages (from panel) (2.2.0)
# Requirement already satisfied: linkify-it-py in c:\users\jake\anaconda3\lib\site-packages (from panel) (2.0.0)
# Requirement already satisfied: mdit-py-plugins in c:\users\jake\anaconda3\lib\site-packages (from panel) (0.3.0)
# Requirement already satisfied: requests in c:\users\jake\anaconda3\lib\site-packages (from panel) (2.29.0)
# Requirement already satisfied: tqdm>=4.48.0 in c:\users\jake\anaconda3\lib\site-packages (from panel) (4.65.0)
# Requirement already satisfied: bleach in c:\users\jake\anaconda3\lib\site-packages (from panel) (4.1.0)
# Requirement already satisfied: typing-extensions in c:\users\jake\anaconda3\lib\site-packages (from panel) (4.6.3)
# Requirement already satisfied: pandas>=1.2 in c:\users\jake\anaconda3\lib\site-packages (from panel) (1.5.3)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\jake\anaconda3\lib\site-packages (from bokeh<3.2.0,>=3.1.1->panel) (3.1.2)
# Requirement already satisfied: contourpy>=1 in c:\users\jake\anaconda3\lib\site-packages (from bokeh<3.2.0,>=3.1.1->panel) (1.0.5)
# Requirement already satisfied: numpy>=1.16 in c:\users\jake\anaconda3\lib\site-packages (from bokeh<3.2.0,>=3.1.1->panel) (1.24.3)
# Requirement already satisfied: packaging>=16.8 in c:\users\jake\anaconda3\lib\site-packages (from bokeh<3.2.0,>=3.1.1->panel) (23.0)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\jake\anaconda3\lib\site-packages (from bokeh<3.2.0,>=3.1.1->panel) (9.4.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\jake\anaconda3\lib\site-packages (from bokeh<3.2.0,>=3.1.1->panel) (6.0)
# Requirement already satisfied: tornado>=5.1 in c:\users\jake\anaconda3\lib\site-packages (from bokeh<3.2.0,>=3.1.1->panel) (6.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\jake\anaconda3\lib\site-packages (from markdown-it-py<3->panel) (0.1.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\jake\anaconda3\lib\site-packages (from pandas>=1.2->panel) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jake\anaconda3\lib\site-packages (from pandas>=1.2->panel) (2022.7)
# Requirement already satisfied: colorama in c:\users\jake\anaconda3\lib\site-packages (from tqdm>=4.48.0->panel) (0.4.6)
# Requirement already satisfied: six>=1.9.0 in c:\users\jake\anaconda3\lib\site-packages (from bleach->panel) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\jake\anaconda3\lib\site-packages (from bleach->panel) (0.5.1)
# Requirement already satisfied: uc-micro-py in c:\users\jake\anaconda3\lib\site-packages (from linkify-it-py->panel) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jake\anaconda3\lib\site-packages (from requests->panel) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jake\anaconda3\lib\site-packages (from requests->panel) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jake\anaconda3\lib\site-packages (from requests->panel) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jake\anaconda3\lib\site-packages (from requests->panel) (2023.5.7)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jake\anaconda3\lib\site-packages (from Jinja2>=2.9->bokeh<3.2.0,>=3.1.1->panel) (2.1.1)
# Requirement already satisfied: hvplot in c:\users\jake\anaconda3\lib\site-packages (0.8.4)
# Requirement already satisfied: bokeh>=1.0.0 in c:\users\jake\anaconda3\lib\site-packages (from hvplot) (3.1.1)
# Requirement already satisfied: colorcet>=2 in c:\users\jake\anaconda3\lib\site-packages (from hvplot) (3.0.1)
# Requirement already satisfied: holoviews>=1.11.0 in c:\users\jake\anaconda3\lib\site-packages (from hvplot) (1.16.2)
# Requirement already satisfied: pandas in c:\users\jake\anaconda3\lib\site-packages (from hvplot) (1.5.3)
# Requirement already satisfied: numpy>=1.15 in c:\users\jake\anaconda3\lib\site-packages (from hvplot) (1.24.3)
# Requirement already satisfied: packaging in c:\users\jake\anaconda3\lib\site-packages (from hvplot) (23.0)
# Requirement already satisfied: panel>=0.11.0 in c:\users\jake\anaconda3\lib\site-packages (from hvplot) (1.1.0)
# Requirement already satisfied: param>=1.9.0 in c:\users\jake\anaconda3\lib\site-packages (from hvplot) (1.13.0)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\jake\anaconda3\lib\site-packages (from bokeh>=1.0.0->hvplot) (3.1.2)
# Requirement already satisfied: contourpy>=1 in c:\users\jake\anaconda3\lib\site-packages (from bokeh>=1.0.0->hvplot) (1.0.5)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\jake\anaconda3\lib\site-packages (from bokeh>=1.0.0->hvplot) (9.4.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\jake\anaconda3\lib\site-packages (from bokeh>=1.0.0->hvplot) (6.0)
# Requirement already satisfied: tornado>=5.1 in c:\users\jake\anaconda3\lib\site-packages (from bokeh>=1.0.0->hvplot) (6.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\jake\anaconda3\lib\site-packages (from bokeh>=1.0.0->hvplot) (2022.9.0)
# Requirement already satisfied: pyct>=0.4.4 in c:\users\jake\anaconda3\lib\site-packages (from colorcet>=2->hvplot) (0.5.0)
# Requirement already satisfied: pyviz-comms>=0.7.4 in c:\users\jake\anaconda3\lib\site-packages (from holoviews>=1.11.0->hvplot) (2.3.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\jake\anaconda3\lib\site-packages (from pandas->hvplot) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jake\anaconda3\lib\site-packages (from pandas->hvplot) (2022.7)
# Requirement already satisfied: markdown in c:\users\jake\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (3.4.1)
# Requirement already satisfied: markdown-it-py<3 in c:\users\jake\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (2.2.0)
# Requirement already satisfied: linkify-it-py in c:\users\jake\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (2.0.0)
# Requirement already satisfied: mdit-py-plugins in c:\users\jake\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (0.3.0)
# Requirement already satisfied: requests in c:\users\jake\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (2.29.0)
# Requirement already satisfied: tqdm>=4.48.0 in c:\users\jake\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (4.65.0)
# Requirement already satisfied: bleach in c:\users\jake\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (4.1.0)
# Requirement already satisfied: typing-extensions in c:\users\jake\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (4.6.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jake\anaconda3\lib\site-packages (from Jinja2>=2.9->bokeh>=1.0.0->hvplot) (2.1.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\jake\anaconda3\lib\site-packages (from markdown-it-py<3->panel>=0.11.0->hvplot) (0.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\jake\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->hvplot) (1.16.0)
# Requirement already satisfied: colorama in c:\users\jake\anaconda3\lib\site-packages (from tqdm>=4.48.0->panel>=0.11.0->hvplot) (0.4.6)
# Requirement already satisfied: webencodings in c:\users\jake\anaconda3\lib\site-packages (from bleach->panel>=0.11.0->hvplot) (0.5.1)
# Requirement already satisfied: uc-micro-py in c:\users\jake\anaconda3\lib\site-packages (from linkify-it-py->panel>=0.11.0->hvplot) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jake\anaconda3\lib\site-packages (from requests->panel>=0.11.0->hvplot) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jake\anaconda3\lib\site-packages (from requests->panel>=0.11.0->hvplot) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jake\anaconda3\lib\site-packages (from requests->panel>=0.11.0->hvplot) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jake\anaconda3\lib\site-packages (from requests->panel>=0.11.0->hvplot) (2023.5.7)
# Requirement already satisfied: holoviews in c:\users\jake\anaconda3\lib\site-packages (1.16.2)
# Requirement already satisfied: param<3.0,>=1.12.0 in c:\users\jake\anaconda3\lib\site-packages (from holoviews) (1.13.0)
# Requirement already satisfied: numpy>=1.0 in c:\users\jake\anaconda3\lib\site-packages (from holoviews) (1.24.3)
# Requirement already satisfied: pyviz-comms>=0.7.4 in c:\users\jake\anaconda3\lib\site-packages (from holoviews) (2.3.0)
# Requirement already satisfied: panel>=0.13.1 in c:\users\jake\anaconda3\lib\site-packages (from holoviews) (1.1.0)
# Requirement already satisfied: colorcet in c:\users\jake\anaconda3\lib\site-packages (from holoviews) (3.0.1)
# Requirement already satisfied: packaging in c:\users\jake\anaconda3\lib\site-packages (from holoviews) (23.0)
# Requirement already satisfied: pandas>=0.20.0 in c:\users\jake\anaconda3\lib\site-packages (from holoviews) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\jake\anaconda3\lib\site-packages (from pandas>=0.20.0->holoviews) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jake\anaconda3\lib\site-packages (from pandas>=0.20.0->holoviews) (2022.7)
# Requirement already satisfied: bokeh<3.2.0,>=3.1.1 in c:\users\jake\anaconda3\lib\site-packages (from panel>=0.13.1->holoviews) (3.1.1)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\jake\anaconda3\lib\site-packages (from panel>=0.13.1->holoviews) (2022.9.0)
# Requirement already satisfied: markdown in c:\users\jake\anaconda3\lib\site-packages (from panel>=0.13.1->holoviews) (3.4.1)
# Requirement already satisfied: markdown-it-py<3 in c:\users\jake\anaconda3\lib\site-packages (from panel>=0.13.1->holoviews) (2.2.0)
# Requirement already satisfied: linkify-it-py in c:\users\jake\anaconda3\lib\site-packages (from panel>=0.13.1->holoviews) (2.0.0)
# Requirement already satisfied: mdit-py-plugins in c:\users\jake\anaconda3\lib\site-packages (from panel>=0.13.1->holoviews) (0.3.0)
# Requirement already satisfied: requests in c:\users\jake\anaconda3\lib\site-packages (from panel>=0.13.1->holoviews) (2.29.0)
# Requirement already satisfied: tqdm>=4.48.0 in c:\users\jake\anaconda3\lib\site-packages (from panel>=0.13.1->holoviews) (4.65.0)
# Requirement already satisfied: bleach in c:\users\jake\anaconda3\lib\site-packages (from panel>=0.13.1->holoviews) (4.1.0)
# Requirement already satisfied: typing-extensions in c:\users\jake\anaconda3\lib\site-packages (from panel>=0.13.1->holoviews) (4.6.3)
# Requirement already satisfied: pyct>=0.4.4 in c:\users\jake\anaconda3\lib\site-packages (from colorcet->holoviews) (0.5.0)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\jake\anaconda3\lib\site-packages (from bokeh<3.2.0,>=3.1.1->panel>=0.13.1->holoviews) (3.1.2)
# Requirement already satisfied: contourpy>=1 in c:\users\jake\anaconda3\lib\site-packages (from bokeh<3.2.0,>=3.1.1->panel>=0.13.1->holoviews) (1.0.5)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\jake\anaconda3\lib\site-packages (from bokeh<3.2.0,>=3.1.1->panel>=0.13.1->holoviews) (9.4.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\jake\anaconda3\lib\site-packages (from bokeh<3.2.0,>=3.1.1->panel>=0.13.1->holoviews) (6.0)
# Requirement already satisfied: tornado>=5.1 in c:\users\jake\anaconda3\lib\site-packages (from bokeh<3.2.0,>=3.1.1->panel>=0.13.1->holoviews) (6.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\jake\anaconda3\lib\site-packages (from markdown-it-py<3->panel>=0.13.1->holoviews) (0.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\jake\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.20.0->holoviews) (1.16.0)
# Requirement already satisfied: colorama in c:\users\jake\anaconda3\lib\site-packages (from tqdm>=4.48.0->panel>=0.13.1->holoviews) (0.4.6)
# Requirement already satisfied: webencodings in c:\users\jake\anaconda3\lib\site-packages (from bleach->panel>=0.13.1->holoviews) (0.5.1)
# Requirement already satisfied: uc-micro-py in c:\users\jake\anaconda3\lib\site-packages (from linkify-it-py->panel>=0.13.1->holoviews) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jake\anaconda3\lib\site-packages (from requests->panel>=0.13.1->holoviews) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jake\anaconda3\lib\site-packages (from requests->panel>=0.13.1->holoviews) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jake\anaconda3\lib\site-packages (from requests->panel>=0.13.1->holoviews) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jake\anaconda3\lib\site-packages (from requests->panel>=0.13.1->holoviews) (2023.5.7)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jake\anaconda3\lib\site-packages (from Jinja2>=2.9->bokeh<3.2.0,>=3.1.1->panel>=0.13.1->holoviews) (2.1.1)
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
#Connect data source

import os

os.getcwd()
# Out:
# 'C:\\Users\\Jake\\OneDrive\\Desktop'

# %%
os.chdir('C:\\Users\\Jake\\OneDrive\\Desktop')

df = pd.read_csv('Sample_Bank_Data.csv')

df
# Out:
#        Type  Product Started Date Completed Date      Description   Amount  \
# 0     DEBIT  Current    8/11/2023      8/11/2023  Vending Machine    -2.40
# 1     DEBIT  Current    8/14/2023      8/14/2023   ChristianaCare  -155.00
# 2     DEBIT  Current    8/14/2023      8/14/2023       ShakeShack   -33.56
# 3      ELEC  Current    8/14/2023      8/14/2023       CapitalOne  -317.14
# 4     DEBIT  Current    8/15/2023      8/15/2023     NordProducts   -18.28
# 5     DEBIT  Current    8/15/2023      8/15/2023         TacoBell   -31.32
# 6      ELEC  Current    8/16/2023      8/16/2023             USAA   -46.75
# 7     DEBIT  Current    8/21/2023      8/21/2023           Amazon   -11.95
# 8     DEBIT  Current    8/21/2023      8/21/2023           Amazon   -25.00
# 9     DEBIT  Current    8/21/2023      8/21/2023       Parkmobile    -0.45
# 10    DEBIT  Current    8/21/2023      8/21/2023           Amazon   -11.43
# 11    DEBIT  Current    8/22/2023      8/22/2023        Starbucks   -25.00
# 12    DEBIT  Current    8/22/2023      8/22/2023         Coursera   -39.00
# 13    DEBIT  Current    8/22/2023      8/22/2023        EmpowerMe    -8.00
# 14    DEBIT  Current    8/22/2023      8/22/2023           Amazon    -7.99
# 15     ELEC  Current    8/22/2023      8/22/2023       CapitalOne  -133.20
# 16    DEBIT  Current    8/24/2023      8/24/2023            Apple    -2.99
# 17    DEBIT  Current    8/24/2023      8/24/2023         Coursera   -39.00
# 18  DEPOSIT  Current    8/25/2023      8/25/2023         PowerHRG  2171.62
# 19    DEBIT  Current    8/28/2023      8/28/2023           Albert    -8.00
# 20    DEBIT  Current    8/28/2023      8/28/2023           Amazon    -8.99
# 21    DEBIT  Current    8/28/2023      8/28/2023            Apple   -18.99
# 22    DEBIT  Current    8/28/2023      8/28/2023      PlayStation   -14.99
# 23     ELEC  Current    8/28/2023      8/28/2023       CapitalOne   -63.97
# 24     ELEC  Current    8/28/2023      8/28/2023       CapitalOne  -317.95
# 25    DEBIT  Current    8/31/2023      8/31/2023          Peacock    -5.99
# 26     ELEC  Current     9/1/2023       9/1/2023            Zelle  -977.00
# 27    DEBIT  Current     9/5/2023       9/5/2023        Starbucks   -25.00
# 28    DEBIT  Current     9/5/2023       9/5/2023        Microsoft   -16.99
# 29     ELEC  Current     9/5/2023       9/5/2023             USAA   -46.76
# 30    DEBIT  Current     9/6/2023       9/6/2023          Patreon    -5.00
# 31    DEBIT  Current     9/7/2023       9/7/2023          UnivLqr   -13.99
# 32    DEBIT  Current     9/7/2023       9/7/2023  Vending Machine    -2.00
# 33  DEPOSIT  Current     9/8/2023       9/8/2023         PowerHRG  1561.89
# 34    DEBIT  Current     9/8/2023       9/8/2023         GridIron   -37.08
#
#     Fee Currency      State  Balance
# 0     0      USD  Completed  1506.48
# 1     0      USD  Completed  1351.48
# 2     0      USD  Completed  1317.92
# 3     0      USD  Completed  1000.78
# 4     0      USD  Completed   982.50
# 5     0      USD  Completed   951.18
# 6     0      USD  Completed   904.43
# 7     0      USD  Completed   892.48
# 8     0      USD  Completed   867.48
# 9     0      USD  Completed   867.03
# 10    0      USD  Completed   855.60
# 11    0      USD  Completed   830.60
# 12    0      USD  Completed   791.60
# 13    0      USD  Completed   783.60
# 14    0      USD  Completed   775.61
# 15    0      USD  Completed   642.41
# 16    0      USD  Completed   639.42
# 17    0      USD  Completed   600.42
# 18    0      USD  Completed  2772.04
# 19    0      USD  Completed  2764.04
# 20    0      USD  Completed  2755.05
# 21    0      USD  Completed  2736.06
# 22    0      USD  Completed  2721.07
# 23    0      USD  Completed  2657.10
# 24    0      USD  Completed  2339.15
# 25    0      USD  Completed  2333.16
# 26    0      USD  Completed  1356.16
# 27    0      USD  Completed  1331.16
# 28    0      USD  Completed  1314.17
# 29    0      USD  Completed  1267.41
# 30    0      USD  Completed  1262.41
# 31    0      USD  Completed  1248.42
# 32    0      USD  Completed  1246.42
# 33    0      USD  Completed  2808.31
# 34    0      USD  Completed  2771.23

# %%
#Clean data

df = df[['Completed Date', 'Description', 'Amount',]] #keep only desired columns
df['Description'] = df['Description'].map(str.lower) #lower case of descriptions

df = df.rename(columns={'Completed Date' : 'Date'}) #rename columns
df['Category'] = 'unassigned' #add category column

df.head()
# Out:
#         Date      Description  Amount    Category
# 0  8/11/2023  vending machine   -2.40  unassigned
# 1  8/14/2023   christianacare -155.00  unassigned
# 2  8/14/2023       shakeshack  -33.56  unassigned
# 3  8/14/2023       capitalone -317.14  unassigned
# 4  8/15/2023     nordproducts  -18.28  unassigned

# %%
#define all categories
    # Bills
    # Food
    # Shopping
    # Transport
    # Entertainment
    # Services
    # Excluded

# %%
#Assign transactions to the correct category

# Bills

df['Category'] = np.where(df['Description'].str.contains(
    'christianacare|capitalone|usaa|zelle'), 'Bills', df['Category'])

# Food

df['Category'] = np.where(df['Description'].str.contains(
    'vending machine|tacobell|shakeshack|gridiron|starbucks|univlqr'), 'Food', df['Category'])

# Shopping

df['Category'] = np.where(df['Description'].str.contains(
    'amazon'), 'Shopping', df['Category'])

# Services

df['Category'] = np.where(df['Description'].str.contains(
    'coursera|empowerme|albert|apple|peacock|nordproducts|patreon'), 'Services', df['Category'])

# Entertainment

df['Category'] = np.where(df['Description'].str.contains('playstation|microsoft'), 'Entertainment', df['Category'])

# Transport

df['Category'] = np.where(df['Description'].str.contains('parkmobile'), 'Transport', df['Category'])

# Paycheck

df['Category'] = np.where(df['Description'].str.contains('powerhrg'), 'Paycheck', df['Category'])

# Convert the "Date" column to a datetime format
df['Date'] = pd.to_datetime(df['Date'])

# Extract the month and year information
df['Month'] = df['Date'].dt.month
df['Year'] = df['Date'].dt.year

pd.options.display.max_rows = 999
df.head(200)
# Out:
#          Date      Description   Amount       Category  Month  Year
# 0  2023-08-11  vending machine    -2.40           Food      8  2023
# 1  2023-08-14   christianacare  -155.00          Bills      8  2023
# 2  2023-08-14       shakeshack   -33.56           Food      8  2023
# 3  2023-08-14       capitalone  -317.14          Bills      8  2023
# 4  2023-08-15     nordproducts   -18.28       Services      8  2023
# 5  2023-08-15         tacobell   -31.32           Food      8  2023
# 6  2023-08-16             usaa   -46.75          Bills      8  2023
# 7  2023-08-21           amazon   -11.95       Shopping      8  2023
# 8  2023-08-21           amazon   -25.00       Shopping      8  2023
# 9  2023-08-21       parkmobile    -0.45      Transport      8  2023
# 10 2023-08-21           amazon   -11.43       Shopping      8  2023
# 11 2023-08-22        starbucks   -25.00           Food      8  2023
# 12 2023-08-22         coursera   -39.00       Services      8  2023
# 13 2023-08-22        empowerme    -8.00       Services      8  2023
# 14 2023-08-22           amazon    -7.99       Shopping      8  2023
# 15 2023-08-22       capitalone  -133.20          Bills      8  2023
# 16 2023-08-24            apple    -2.99       Services      8  2023
# 17 2023-08-24         coursera   -39.00       Services      8  2023
# 18 2023-08-25         powerhrg  2171.62       Paycheck      8  2023
# 19 2023-08-28           albert    -8.00       Services      8  2023
# 20 2023-08-28           amazon    -8.99       Shopping      8  2023
# 21 2023-08-28            apple   -18.99       Services      8  2023
# 22 2023-08-28      playstation   -14.99  Entertainment      8  2023
# 23 2023-08-28       capitalone   -63.97          Bills      8  2023
# 24 2023-08-28       capitalone  -317.95          Bills      8  2023
# 25 2023-08-31          peacock    -5.99       Services      8  2023
# 26 2023-09-01            zelle  -977.00          Bills      9  2023
# 27 2023-09-05        starbucks   -25.00           Food      9  2023
# 28 2023-09-05        microsoft   -16.99  Entertainment      9  2023
# 29 2023-09-05             usaa   -46.76          Bills      9  2023
# 30 2023-09-06          patreon    -5.00       Services      9  2023
# 31 2023-09-07          univlqr   -13.99           Food      9  2023
# 32 2023-09-07  vending machine    -2.00           Food      9  2023
# 33 2023-09-08         powerhrg  1561.89       Paycheck      9  2023
# 34 2023-09-08         gridiron   -37.08           Food      9  2023

# %%
# Check unassigned transactions and confirm all transactions are assigned to a category

unassigned = df.loc[df['Category'] == 'unassigned']
unassigned
# Out:
# Empty DataFrame
# Columns: [Date, Description, Amount, Category, Month, Year]
# Index: []

# %%
# Create Top Banner for a summary of last month's income, recurring expenses, non-recurring expenses, and savings

# %%
# Get the latest month and year
latest_month = df['Month'].max()
latest_year = df['Year'].max()

# Filter the dataframe to include only transactions from the lastest month
last_month_expenses = df[(df['Month'] == latest_month) & (df['Year'] == latest_year)]

# %%
last_month_expenses = last_month_expenses.groupby('Category')['Amount'].sum().reset_index()

last_month_expenses['Amount']=last_month_expenses['Amount'].astype('str')
last_month_expenses['Amount']=last_month_expenses['Amount'].str.replace('-', '')
last_month_expenses['Amount']=last_month_expenses['Amount'].astype('float')    #get absolute figures

last_month_expenses = last_month_expenses[last_month_expenses["Category"].str.contains("Excluded|unassigned|Paycheck") == False]
last_month_expenses = last_month_expenses.sort_values(by= 'Amount', ascending = False)   #sort values
last_month_expenses['Amount'] = last_month_expenses['Amount'].round().astype(int)         #round values

last_month_expenses
# Out:
#         Category  Amount
# 0          Bills    1024
# 2           Food      78
# 1  Entertainment      17
# 4       Services       5

# %%
last_month_expenses_tot = last_month_expenses['Amount'].sum()
last_month_expenses_tot
# Out:
# 1124

# %%
def calculate_difference(event):
    income = float(income_widget.value)
    recurring_expenses = float(recurring_expenses_widget.value)
    monthly_expenses = float(monthly_expenses_widget.value)
    difference = income - recurring_expenses - monthly_expenses
    difference_widget.value = str(difference)
    
income_widget = pn.widgets.TextInput(name="Income", value="0")
recurring_expenses_widget = pn.widgets.TextInput(name="Recurring Expenses", value="0")
monthly_expenses_widget = pn.widgets.TextInput(name="Non-Recurring Expenses", value=str(last_month_expenses_tot))
difference_widget = pn.widgets.TextInput(name="Last Month's Savings", value="0")
    
income_widget.param.watch(calculate_difference, "value")
recurring_expenses_widget.param.watch(calculate_difference, "value")
monthly_expenses_widget.param.watch(calculate_difference, "value")
    
pn.Row(income_widget, recurring_expenses_widget,  monthly_expenses_widget, difference_widget).show()
# Out:
# Launching server at http://localhost:59979

# %%
# Create last month expenses bar chart

last_month_expenses_chart = last_month_expenses.hvplot.bar(
    x='Category',
    y='Amount',
    height=250,
    width=850,
    title="Last Month Expenses",
    ylim=(0, 500))

last_month_expenses_chart
# Out:
# :Bars   [Category]   (Amount)

# %%
# Create monthly expenses trend bar chart

df['Date'] = pd.to_datetime(df['Date'])               #convert the 'Date' column to a datetime object
df['Month-Year'] = df['Date'].dt.to_period('M')       #extract the month and year from the 'Date' column and create a new coulmn
monthly_expenses_trend_by_cat = df.groupby(['Month-Year', 'Category'])['Amount'].sum().reset_index()

monthly_expenses_trend_by_cat['Amount']=monthly_expenses_trend_by_cat['Amount'].astype('str')
monthly_expenses_trend_by_cat['Amount']=monthly_expenses_trend_by_cat['Amount'].str.replace('-', '')
monthly_expenses_trend_by_cat['Amount']=monthly_expenses_trend_by_cat['Amount'].astype('float')
monthly_expenses_trend_by_cat = monthly_expenses_trend_by_cat[monthly_expenses_trend_by_cat["Category"].str.contains("Excluded|unassigned|Paycheck") == False]

monthly_expenses_trend_by_cat = monthly_expenses_trend_by_cat.sort_values(by='Amount', ascending=False)
monthly_expenses_trend_by_cat['Amount'] = monthly_expenses_trend_by_cat['Amount'].round().astype(int)
monthly_expenses_trend_by_cat['Month-Year'] = monthly_expenses_trend_by_cat['Month-Year'].astype(str)
monthly_expenses_trend_by_cat = monthly_expenses_trend_by_cat.rename(columns={'Amount': 'Amount '})   
                                                              
monthly_expenses_trend_by_cat
# Out:
#   Month-Year       Category  Amount
# 0    2023-08          Bills     1034
# 6    2023-09          Bills     1024
# 3    2023-08       Services      140
# 2    2023-08           Food       92
# 8    2023-09           Food       78
# 4    2023-08       Shopping       65
# 7    2023-09  Entertainment       17
# 1    2023-08  Entertainment       15
# 9    2023-09       Services        5
# 5    2023-08      Transport        0

# %%
# Define Panel Widget

select_category1 = pn.widgets.Select(name='Select Category', options=[
    'All',
    'Bills',
    'Services',
    'Food',
    'Entertainment',
    'Shopping',
    'Transport',
    #'Excluded'
])

select_category1
# Out:
# Select(options=['All', 'Bills', ...], value='All')

# %%
# Define plot function

def plot_expenses(category):
    if category == 'All':
        plot_df = monthly_expenses_trend_by_cat.groupby('Month-Year').sum()
    else:
        plot_df = monthly_expenses_trend_by_cat[monthly_expenses_trend_by_cat['Category'] == category].groupby('Month-Year').sum()
    plot = plot_df.hvplot.bar(x='Month-Year', y='Amount ')
    return plot

# Define callback function

@pn.depends(select_category1.param.value)
def update_plot(category):
    plot = plot_expenses(category)
    return plot

# Create layout

monthly_expenses_trend_by_cat_chart = pn.Row(select_category1, update_plot)
monthly_expenses_trend_by_cat_chart[1].width = 600

monthly_expenses_trend_by_cat_chart
# Out:
# C:\Users\Jake\AppData\Local\Temp\ipykernel_13796\1841426744.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   plot_df = monthly_expenses_trend_by_cat.groupby('Month-Year').sum()
# Row
#     [0] Select(options=['All', 'Bills', ...], value='All')
#     [1] ParamFunction(function, _pane=HoloViews, width=600)

# %%
# Create Summary Table

df = df[['Date', 'Category', 'Description', 'Amount']]
df['Amount']=df['Amount'].astype('str')
df['Amount']=df['Amount'].str.replace('-', '')
df['Amount']=df['Amount'].astype('float')                #get absolute figures

df = df[df["Category"].str.contains("Excluded|Paycheck") ==False]     
df['Amount'] = df['Amount'].round().astype(int)
df
# Out:
#          Date       Category      Description  Amount
# 0  2023-08-11           Food  vending machine       2
# 1  2023-08-14          Bills   christianacare     155
# 2  2023-08-14           Food       shakeshack      34
# 3  2023-08-14          Bills       capitalone     317
# 4  2023-08-15       Services     nordproducts      18
# 5  2023-08-15           Food         tacobell      31
# 6  2023-08-16          Bills             usaa      47
# 7  2023-08-21       Shopping           amazon      12
# 8  2023-08-21       Shopping           amazon      25
# 9  2023-08-21      Transport       parkmobile       0
# 10 2023-08-21       Shopping           amazon      11
# 11 2023-08-22           Food        starbucks      25
# 12 2023-08-22       Services         coursera      39
# 13 2023-08-22       Services        empowerme       8
# 14 2023-08-22       Shopping           amazon       8
# 15 2023-08-22          Bills       capitalone     133
# 16 2023-08-24       Services            apple       3
# 17 2023-08-24       Services         coursera      39
# 19 2023-08-28       Services           albert       8
# 20 2023-08-28       Shopping           amazon       9
# 21 2023-08-28       Services            apple      19
# 22 2023-08-28  Entertainment      playstation      15
# 23 2023-08-28          Bills       capitalone      64
# 24 2023-08-28          Bills       capitalone     318
# 25 2023-08-31       Services          peacock       6
# 26 2023-09-01          Bills            zelle     977
# 27 2023-09-05           Food        starbucks      25
# 28 2023-09-05  Entertainment        microsoft      17
# 29 2023-09-05          Bills             usaa      47
# 30 2023-09-06       Services          patreon       5
# 31 2023-09-07           Food          univlqr      14
# 32 2023-09-07           Food  vending machine       2
# 34 2023-09-08           Food         gridiron      37

# %%
# Define a function to filter the dataframe based on the selected category

def filter_df(category):
    if category == 'All':
        return df
    return df[df['Category'] == category]

#Create a DataFrame widget that updates based on the category filter
summary_table = pn.widgets.DataFrame(filter_df('All'), height = 300,width=400)

# Define a callback that updates the dataframe widget when the category filter is changed
def update_summary_table(event):
    summary_table.value = filter_df(event.new)

# Add the callback function to the category widget

select_category1.param.watch(update_summary_table, 'value')

summary_table
# Out:
# DataFrame(height=300, sizing_mode='fixed', value=         Date  ..., width=400)

# %%
# Create Final Dashboard

template = pn.template.FastListTemplate(
    title="Personal Finances Summary",
    sidebar=[
        pn.pane.Markdown("## *If you can't manage your money, making more won't help*"),
        pn.pane.PNG('http://localhost:8888/view/vecteezy_pack-of-dollars-money-clipart-design-illustration_9391394_241.png', sizing_mode='scale_both'),
        pn.pane.Markdown(""),
        pn.pane.Markdown(""),
        select_category1],
    main=[
        pn.Row(income_widget, recurring_expenses_widget, monthly_expenses_widget, difference_widget, width=950),
        pn.Row(last_month_expenses_chart, height=240),
        pn.GridBox(
            monthly_expenses_trend_cat_chart[1],
            summary_table,
            ncols=2,
            width=500,
            align='start',
            sizing_mode='stretch_width')])

template.show()
# Out:
# WARNING:param.GridBox: Providing a width-responsive sizing_mode ('stretch_width') and a fixed width is not supported. Converting fixed width to min_width. If you intended the component to be fully width-responsive remove the heightsetting, otherwise change it to min_height. To error on the incorrect specification disable the config.layout_compatibility option.
# Launching server at http://localhost:53926
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Row(id='fcfc8d96-c677-4a5a-beea-991a3bb251c3', ...)
